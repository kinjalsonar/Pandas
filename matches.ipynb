# %% [markdown]
# <a href="https://colab.research.google.com/github/kinjalsonar/Pandas/blob/master/matches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # How to read CSV file in Pandas

# %%
data=pd.read_csv('matches.csv')

# %% [markdown]
# # head() will show top columns of dataset

# %%
data.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %% [markdown]
# # tail() will show bottom columns of dataset

# %%
data.tail()
# Out:
#         id  season  ...         umpire2                  umpire3
# 751  11347    2019  ...        O Nandan                   S Ravi
# 752  11412    2019  ...     Nitin Menon                Ian Gould
# 753  11413    2019  ...             NaN                      NaN
# 754  11414    2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415    2019  ...       Ian Gould              Nigel Llong
#
# [5 rows x 18 columns]

# %% [markdown]
# #Returns column names

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# #Retruns columns data types

# %%
data.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %% [markdown]
# This returns [rows, columns] of the dataset

# %%
data.shape
# Out:
# (756, 18)

# %% [markdown]
# ## **#Summarize Data**
# #Count non-NA/null values of each object

# %%
data.count
# Out:
# <bound method DataFrame.count of         id  season  ...         umpire2                  umpire3
# 0        1    2017  ...        NJ Llong                      NaN
# 1        2    2017  ...          S Ravi                      NaN
# 2        3    2017  ...       CK Nandan                      NaN
# 3        4    2017  ...   C Shamshuddin                      NaN
# 4        5    2017  ...             NaN                      NaN
# ..     ...     ...  ...             ...                      ...
# 751  11347    2019  ...        O Nandan                   S Ravi
# 752  11412    2019  ...     Nitin Menon                Ian Gould
# 753  11413    2019  ...             NaN                      NaN
# 754  11414    2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415    2019  ...       Ian Gould              Nigel Llong
#
# [756 rows x 18 columns]>

# %% [markdown]
# #  No. of rows in dataset

# %%
len(data)
# Out:
# 756

# %% [markdown]
# #Sum value of each object

# %%
data.sum()
# Out:
# id                                                          1354887
# season                                                      1522164
# date              05-04-201706-04-201707-04-201708-04-201709-04-...
# team1             Sunrisers HyderabadMumbai IndiansGujarat Lions...
# team2             Royal Challengers BangaloreRising Pune Supergi...
# toss_winner       Royal Challengers BangaloreRising Pune Supergi...
# toss_decision     fieldfieldfieldfieldbatfieldfieldbatfieldfield...
# result            normalnormalnormalnormalnormalnormalnormalnorm...
# dl_applied                                                       19
# win_by_runs                                                   10042
# win_by_wickets                                                 2533
# venue             Rajiv Gandhi International Stadium, UppalMahar...
# dtype: object

# %% [markdown]
# #Retruns MIN values
# # Retruns MAX values
# #Retruns MEAN values
# #Retruns VAR values
# #Retruns STD values
# #Retruns MEDIAN values

# %%
data.min()
# Out:
# id                                  1
# season                           2008
# date                       01-01-2018
# team1             Chennai Super Kings
# team2             Chennai Super Kings
# toss_winner       Chennai Super Kings
# toss_decision                     bat
# result                      no result
# dl_applied                          0
# win_by_runs                         0
# win_by_wickets                      0
# venue                ACA-VDCA Stadium
# dtype: object

# %%
data.max()
# Out:
# id                              11415
# season                           2019
# date                       31-12-2017
# team1             Sunrisers Hyderabad
# team2             Sunrisers Hyderabad
# toss_winner       Sunrisers Hyderabad
# toss_decision                   field
# result                            tie
# dl_applied                          1
# win_by_runs                       146
# win_by_wickets                     10
# venue                Wankhede Stadium
# dtype: object

# %%
data.mean()
# Out:
# id                1792.178571
# season            2013.444444
# dl_applied           0.025132
# win_by_runs         13.283069
# win_by_wickets       3.350529
# dtype: float64

# %%
data.var()
# Out:
# id                1.200261e+07
# season            1.133598e+01
# dl_applied        2.453310e-02
# win_by_runs       5.508946e+02
# win_by_wickets    1.147829e+01
# dtype: float64

# %%
data.std()
# Out:
# id                3464.478148
# season               3.366895
# dl_applied           0.156630
# win_by_runs         23.471144
# win_by_wickets       3.387963
# dtype: float64

# %%
data.median()
# Out:
# id                 378.5
# season            2013.0
# dl_applied           0.0
# win_by_runs          0.0
# win_by_wickets       4.0
# dtype: float64

# %% [markdown]
# #Returns distinct values of each column

# %%
data.nunique()
# Out:
# id                 756
# season              12
# city                32
# date               634
# team1               15
# team2               15
# toss_winner         15
# toss_decision        2
# result               3
# dl_applied           2
# winner              15
# win_by_runs         89
# win_by_wickets      11
# player_of_match    226
# venue               41
# umpire1             61
# umpire2             65
# umpire3             25
# dtype: int64

# %% [markdown]
# #Count number of rows with each unique value of variable

# %%
data['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %% [markdown]
# #Basic descriptive statistics for each column

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %% [markdown]
# # **#Handling missing values**
# #Drop rows with any column having NA/null data.

# %%
data.dropna()
# Out:
#         id  season  ...               umpire2                  umpire3
# 636   7894    2018  ...       A Nanda Kishore           Anil Chaudhary
# 637   7895    2018  ...  K Ananthapadmanabhan              Nitin Menon
# 638   7896    2018  ...          A.D Deshmukh                   S Ravi
# 639   7897    2018  ...       Vineet Kulkarni                 O Nandan
# 640   7898    2018  ...        Chris Gaffaney          A Nanda Kishore
# ..     ...     ...  ...                   ...                      ...
# 750  11346    2019  ...         C Shamshuddin           Bruce Oxenford
# 751  11347    2019  ...              O Nandan                   S Ravi
# 752  11412    2019  ...           Nitin Menon                Ian Gould
# 754  11414    2019  ...        Bruce Oxenford  Chettithody Shamshuddin
# 755  11415    2019  ...             Ian Gould              Nigel Llong
#
# [118 rows x 18 columns]

# %%
data.drop(columns=['season','winner','win_by_runs'])
# Out:
#         id           city  ...         umpire2                  umpire3
# 0        1      Hyderabad  ...        NJ Llong                      NaN
# 1        2           Pune  ...          S Ravi                      NaN
# 2        3         Rajkot  ...       CK Nandan                      NaN
# 3        4         Indore  ...   C Shamshuddin                      NaN
# 4        5      Bangalore  ...             NaN                      NaN
# ..     ...            ...  ...             ...                      ...
# 751  11347         Mumbai  ...        O Nandan                   S Ravi
# 752  11412        Chennai  ...     Nitin Menon                Ian Gould
# 753  11413  Visakhapatnam  ...             NaN                      NaN
# 754  11414  Visakhapatnam  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415      Hyderabad  ...       Ian Gould              Nigel Llong
#
# [756 rows x 15 columns]

# %% [markdown]
# #Replace all NA/null data with value

# %%
data.fillna(value='win_by_run')
# Out:
#         id  season  ...         umpire2                  umpire3
# 0        1    2017  ...        NJ Llong               win_by_run
# 1        2    2017  ...          S Ravi               win_by_run
# 2        3    2017  ...       CK Nandan               win_by_run
# 3        4    2017  ...   C Shamshuddin               win_by_run
# 4        5    2017  ...      win_by_run               win_by_run
# ..     ...     ...  ...             ...                      ...
# 751  11347    2019  ...        O Nandan                   S Ravi
# 752  11412    2019  ...     Nitin Menon                Ian Gould
# 753  11413    2019  ...      win_by_run               win_by_run
# 754  11414    2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415    2019  ...       Ian Gould              Nigel Llong
#
# [756 rows x 18 columns]

# %%
data.plot.hist()

# %%
data.plot.scatter(x='season',y='date')

# %% [markdown]
# # #Selecting and Filtering Data
# #Selects one column
# #selecting more than one columns

# %%
data['win_by_runs']
# Out:
# 0      35
# 1       0
# 2       0
# 3       0
# 4      15
#        ..
# 751     0
# 752     0
# 753     0
# 754     0
# 755     1
# Name: win_by_runs, Length: 756, dtype: int64

# %%
data[['season','city']]
# Out:
#      season           city
# 0      2017      Hyderabad
# 1      2017           Pune
# 2      2017         Rajkot
# 3      2017         Indore
# 4      2017      Bangalore
# ..      ...            ...
# 751    2019         Mumbai
# 752    2019        Chennai
# 753    2019  Visakhapatnam
# 754    2019  Visakhapatnam
# 755    2019      Hyderabad
#
# [756 rows x 2 columns]

# %% [markdown]
# #Filters all rows and 3 columns
# #loc() function filters by labels

# %%
data.loc[:,['team1','team2','toss_winner']]
# Out:
#                            team1  ...                  toss_winner
# 0            Sunrisers Hyderabad  ...  Royal Challengers Bangalore
# 1                 Mumbai Indians  ...       Rising Pune Supergiant
# 2                  Gujarat Lions  ...        Kolkata Knight Riders
# 3         Rising Pune Supergiant  ...              Kings XI Punjab
# 4    Royal Challengers Bangalore  ...  Royal Challengers Bangalore
# ..                           ...  ...                          ...
# 751        Kolkata Knight Riders  ...               Mumbai Indians
# 752          Chennai Super Kings  ...          Chennai Super Kings
# 753          Sunrisers Hyderabad  ...               Delhi Capitals
# 754               Delhi Capitals  ...          Chennai Super Kings
# 755               Mumbai Indians  ...               Mumbai Indians
#
# [756 rows x 3 columns]

# %% [markdown]
# #filter between 200:650 rows and two cloumns

# %%
data.loc[200:650:,['season','winner']]
# Out:
#      season                       winner
# 200    2010               Mumbai Indians
# 201    2010          Chennai Super Kings
# 202    2010             Delhi Daredevils
# 203    2010        Kolkata Knight Riders
# 204    2010  Royal Challengers Bangalore
# ..      ...                          ...
# 646    2018             Rajasthan Royals
# 647    2018              Kings XI Punjab
# 648    2018        Kolkata Knight Riders
# 649    2018               Mumbai Indians
# 650    2018        Kolkata Knight Riders
#
# [451 rows x 2 columns]

# %% [markdown]
# #Filters all rows and columns from toss winner to winner columns

# %%
data.loc[:,'toss_winner':'winner']
# Out:
#                      toss_winner  ...                       winner
# 0    Royal Challengers Bangalore  ...          Sunrisers Hyderabad
# 1         Rising Pune Supergiant  ...       Rising Pune Supergiant
# 2          Kolkata Knight Riders  ...        Kolkata Knight Riders
# 3                Kings XI Punjab  ...              Kings XI Punjab
# 4    Royal Challengers Bangalore  ...  Royal Challengers Bangalore
# ..                           ...  ...                          ...
# 751               Mumbai Indians  ...               Mumbai Indians
# 752          Chennai Super Kings  ...               Mumbai Indians
# 753               Delhi Capitals  ...               Delhi Capitals
# 754          Chennai Super Kings  ...          Chennai Super Kings
# 755               Mumbai Indians  ...               Mumbai Indians
#
# [756 rows x 5 columns]

# %% [markdown]
# #Filters rows based on condition (winner=Mumbai Indians) and all columns

# %%
data.loc[data['winner']=='Mumbai Indians',]
# Out:
#         id  season  ...         umpire2          umpire3
# 6        7    2017  ...       CK Nandan              NaN
# 9       10    2017  ...       CK Nandan              NaN
# 11      12    2017  ...    AK Chaudhary              NaN
# 15      16    2017  ...          S Ravi              NaN
# 21      22    2017  ...   C Shamshuddin              NaN
# ..     ...     ...  ...             ...              ...
# 739  11335    2019  ...  Anil Chaudhary  Vineet Kulkarni
# 746  11342    2019  ...        O Nandan    Nanda Kishore
# 751  11347    2019  ...        O Nandan           S Ravi
# 752  11412    2019  ...     Nitin Menon        Ian Gould
# 755  11415    2019  ...       Ian Gould      Nigel Llong
#
# [109 rows x 18 columns]

# %% [markdown]
# #Filters all rows and 1 to 6 columns
# #iloc() function filters by index
#
#
# #Filters rows from 150 to 400 and and 2,7,3 columns

# %%
data.iloc[:,1:6]
# Out:
#      season  ...                        team2
# 0      2017  ...  Royal Challengers Bangalore
# 1      2017  ...       Rising Pune Supergiant
# 2      2017  ...        Kolkata Knight Riders
# 3      2017  ...              Kings XI Punjab
# 4      2017  ...             Delhi Daredevils
# ..      ...  ...                          ...
# 751    2019  ...               Mumbai Indians
# 752    2019  ...               Mumbai Indians
# 753    2019  ...               Delhi Capitals
# 754    2019  ...          Chennai Super Kings
# 755    2019  ...          Chennai Super Kings
#
# [756 rows x 5 columns]

# %%
data.iloc[150:400:,[2,7,3]]
# Out:
#                city toss_decision        date
# 150       Kimberley         field  02-09-2017
# 151       Kimberley           bat  03-09-2017
# 152  Port Elizabeth           bat  04-09-2017
# 153    Johannesburg         field  05-09-2017
# 154       Kimberley           bat  06-09-2017
# ..              ...           ...         ...
# 395         Chennai         field  13-04-2013
# 396         Kolkata           bat  14-04-2013
# 397          Jaipur         field  14-04-2013
# 398         Chennai           bat  15-04-2013
# 399      Chandigarh         field  16-04-2013
#
# [250 rows x 3 columns]

# %% [markdown]
# # #Setting and Resetting
# #Sets index based on specified column

# %%
data.set_index('winner')
# Out:
#                                 id  ...                  umpire3
# winner                              ...
# Sunrisers Hyderabad              1  ...                      NaN
# Rising Pune Supergiant           2  ...                      NaN
# Kolkata Knight Riders            3  ...                      NaN
# Kings XI Punjab                  4  ...                      NaN
# Royal Challengers Bangalore      5  ...                      NaN
# ...                            ...  ...                      ...
# Mumbai Indians               11347  ...                   S Ravi
# Mumbai Indians               11412  ...                Ian Gould
# Delhi Capitals               11413  ...                      NaN
# Chennai Super Kings          11414  ...  Chettithody Shamshuddin
# Mumbai Indians               11415  ...              Nigel Llong
#
# [756 rows x 17 columns]

# %%
data.set_index(['team1','team2'])
# Out:
#                                                             id  ...                  umpire3
# team1                       team2                               ...
# Sunrisers Hyderabad         Royal Challengers Bangalore      1  ...                      NaN
# Mumbai Indians              Rising Pune Supergiant           2  ...                      NaN
# Gujarat Lions               Kolkata Knight Riders            3  ...                      NaN
# Rising Pune Supergiant      Kings XI Punjab                  4  ...                      NaN
# Royal Challengers Bangalore Delhi Daredevils                 5  ...                      NaN
# ...                                                        ...  ...                      ...
# Kolkata Knight Riders       Mumbai Indians               11347  ...                   S Ravi
# Chennai Super Kings         Mumbai Indians               11412  ...                Ian Gould
# ...

# %% [markdown]
# #Reset Index

# %%
data.reset_index()
# Out:
#      index     id  ...         umpire2                  umpire3
# 0        0      1  ...        NJ Llong                      NaN
# 1        1      2  ...          S Ravi                      NaN
# 2        2      3  ...       CK Nandan                      NaN
# 3        3      4  ...   C Shamshuddin                      NaN
# 4        4      5  ...             NaN                      NaN
# ..     ...    ...  ...             ...                      ...
# 751    751  11347  ...        O Nandan                   S Ravi
# 752    752  11412  ...     Nitin Menon                Ian Gould
# 753    753  11413  ...             NaN                      NaN
# 754    754  11414  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755    755  11415  ...       Ian Gould              Nigel Llong
#
# [756 rows x 19 columns]
